# %%
# -*- coding: utf-8 -*-
import numpy as np
import pandas as pd
import re
import pyecharts
# %matplotlib inline  # 为了在jupyter notebook里作图，需要用到这个命令

# %%
disease_set_package_file = "../../res/data/disease_set_package1.csv"
disease_set_dict = {}
disease_set_invalid_count = 0

df = pd.read_csv(disease_set_package_file)
df_series = df['疾病集合']

for index, disease_set in df.iterrows():
    diseases = str(disease_set['疾病集合'])
    disease_list = re.split('{|}|"|,|、|，|；|;', diseases)
    for disease_item in disease_list:
        # print(disease_item)
        if disease_item != '{' and disease_item != '}' and disease_item != '' and disease_item != ';' and disease_item != '；' and disease_item != '，' and disease_item != ',':
            if disease_set_dict.__contains__(disease_item):
                disease_set_dict[disease_item] = disease_set_dict[disease_item] + 1
            else:
                disease_set_dict[disease_item] = 1
# print(disease_set_dict)
sorted_array = sorted(disease_set_dict.items(), key=lambda item: item[1])
sorted_array.reverse()
# print(sorted_array)
disease = []
count = []
for key, value in sorted_array[:10]:
    disease.append(key)
    count.append(value)
df_res = pd.DataFrame(data={'disease': disease, 'count': count})
df_res
# Out:
#      disease  count
# 0         包1    150
# 1  严重类风湿性关节炎     74
# 2       恶性肿瘤     67
# 3      严重心肌病     62
# 4   严重溃疡性结肠炎     62
# 5      脊髓灰质炎     60
# 6      严重克隆病     57
# 7      植物人状态     53
# 8     肌营养不良症     52
# 9   慢性呼吸功能衰竭     48

# %%
bar_end_age=pyecharts.Bar("疾病集合分布")
bar_end_age.add('疾病名称',df_res['disease'],df_res['count'],xaxis_type='category',xaxis_interval=0,xaxis_rotate=30,xaxis_label_textsize=8,is_stack=True,mark_line=['average'])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="565f0c0be17f4bd984f2f7e1fcc70c54" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_565f0c0be17f4bd984f2f7e1fcc70c54 = echarts.init(document.getElementById('565f0c0be17f4bd984f2f7e1fcc70c54'), 'light', {renderer: 'canvas'});
#
# var option_565f0c0be17f4bd984f2f7e1fcc70c54 = {
#     "title": [
#         {
#             "text": "\u75be\u75c5\u96c6\u5408\u5206\u5e03",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6852509,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u75be\u75c5\u540d\u79f0",
#             "data": [
#                 150.0,
#                 74.0,
#                 67.0,
#                 62.0,
#                 62.0,
#                 60.0,
#                 57.0,
#                 53.0,
#                 52.0,
#                 48.0
#             ],
#             "stack": "stack_6852509",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 6852509
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u75be\u75c5\u540d\u79f0"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 8
#                 }
#             },
#             "data": [
#                 "\u53051",
#                 "\u4e25\u91cd\u7c7b\u98ce\u6e7f\u6027\u5173\u8282\u708e",
#                 "\u6076\u6027\u80bf\u7624",
#                 "\u4e25\u91cd\u5fc3\u808c\u75c5",
#                 "\u4e25\u91cd\u6e83\u75a1\u6027\u7ed3\u80a0\u708e",
#                 "\u810a\u9ad3\u7070\u8d28\u708e",
#                 "\u4e25\u91cd\u514b\u9686\u75c5",
#                 "\u690d\u7269\u4eba\u72b6\u6001",
#                 "\u808c\u8425\u517b\u4e0d\u826f\u75c7",
#                 "\u6162\u6027\u547c\u5438\u529f\u80fd\u8870\u7aed"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_565f0c0be17f4bd984f2f7e1fcc70c54.setOption(option_565f0c0be17f4bd984f2f7e1fcc70c54);
#
#     });
# </script>
